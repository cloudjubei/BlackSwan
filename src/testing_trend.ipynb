# %%
import sys

sys.path.append('.')

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import torch
import torch.optim as optim
import numpy as np

np.set_printoptions(linewidth=np.inf, precision=2, floatmode='fixed')

# %%
from datamining.mine_json_data import mineData, preparePDData
from indicators.prepare_indicators import prepareIndicators
from predictions.prepare_model_data import prepareModelDataScaleX, prepareDataLoaders
from common.datasets import TimeseriesDataset
from common.models import LSTMLinear
from common.training import fit
from common.checkpoints import loadLSTMLinearFromCheckpoint
from common.losses import R2Loss
from common.plots import printScores
from common.training import getMSEScore, getR2Score

# %%
# mineData("../data/raw", "binance", "BTCUSDT", "1m")
df = preparePDData("../data/raw/binance_BTCUSDT_1m.json")
print(f"df.value_counts: {df.count()}")
# Out:
# df.value_counts: timestamp_open              3083787
# price_open                  3083787
# price_high                  3083787
# price_low                   3083787
# price_close                 3083787
# volume                      3083787
# timestamp_close             3083787
# asset_volume_quote          3083787
# trades_number               3083787
# asset_volume_taker_base     3083787
# asset_volume_taker_quote    3083787
# dtype: int64

# %%
df_1h = preparePDData("../data/raw/binance_BTCUSDT_1h.json")
prepareIndicators(df_1h, 500)
df_1h[["trend_direction", "trend_direction_change", "trend_direction_consecutive", "trend_direction_swing", 'rsi', '24h_price_diff']]
# Out:
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_change].iloc[i] = 1
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_consecutive].iloc[i] = 0
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name].iloc[i] = df[trend_name].iloc[i] / trend_change_amount
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_consecutive].iloc[i] = df[trend_name_consecutive].iloc[i-1] + 1
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_change].iloc[i] = 1
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_consecutive].iloc[i] = 0
# /Users/cloud/Documents/Work/BlackSwan/src/indicators/indicators_common.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[trend_name_consecutive].iloc[i] = df[trend_name_consecutive].iloc[i-1] + 1
#        trend_direction  trend_direction_change  trend_direction_consecutive  \
# 0              0.09470                       1                            0
# 1              0.01298                       0                            1
# 2             -0.01188                       1                            0
# 3              0.06674                       1                            0
# 4              0.05474                       0                            1
# ...                ...                     ...                          ...
# 51407          0.08472                       0                            3
# 51408         -0.04618                       1                            0
# 51409         -0.09070                       0                            1
# 51410         -0.05428                       0                            2
# 51411         -0.10742                       0                            3
#
#        trend_direction_swing
# 0                    0.10460
# 1                    0.07464
# 2                    0.07216
# 3                    0.12516
# 4                    0.08906
# ...                      ...
# 51407                0.15854
# 51408                0.13020
# 51409                0.15286
# 51410                0.18892
# 51411                0.25196
#
# [51412 rows x 4 columns]

# %%
column_y = "trend_direction_change"
# column_names = ["price_open", "price_close", "price_high", "price_low", "volume", "trend_direction", "trend_direction_change", "trend_direction_consecutive", "trend_direction_swing"]
column_names = ["price_open", "price_close", "price_high", "price_low", "volume", "trend_direction", "trend_direction_change", "trend_direction_consecutive", "trend_direction_swing", "rsi", "24h_price_diff"]
model_data = prepareModelDataScaleX(df_1h, column_y=column_y, column_names=column_names)
train_dl, test_dl, val_dl = prepareDataLoaders(model_data)

# %%
num_epochs = 250
learning_rate = 0.1
weight_decay = 1e-2
patience = 15
model_args = {
    'input_size': len(column_names), 
    'hidden_size': 20, 
    'num_layers': 3, 
    'output_size': 1, 
    'scaler': model_data["ss"]
}

# %%
model = LSTMLinear(**model_args)

optimizer_args = { 'params': list(model.parameters()), 'lr': learning_rate, 'weight_decay': weight_decay }
optimizer = optim.AdamW(**optimizer_args)
loss_fn = torch.nn.BCELoss()

filename = "BTCUSDT_1h_trend"

fit(
    model=model, optimizer=optimizer, loss_fn=loss_fn, 
    train_dl=train_dl, val_dl=val_dl, epochs=num_epochs,
    patience=patience,
    save_checkpoints=True, model_args=model_args, optimizer_args=optimizer_args,
    checkpoint_path= f'../data/checkpoints/checkpoint_{filename}.pkl',
    checkpoint_f1_path= f'../data/checkpoints/checkpoint_{filename}_f1.pkl'
)
print('done')
# Out:
# Epoch    1/250 = train loss: 0.7078, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.09406709671020508s
# Epoch    2/250 = train loss: 0.6926, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07574605941772461s
# Epoch    3/250 = train loss: 0.7022, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07775425910949707s
# Epoch    4/250 = train loss: 0.6907, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.0753178596496582s
# Epoch    5/250 = train loss: 0.6901, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07761526107788086s
# Epoch    6/250 = train loss: 0.6905, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07408714294433594s
# Epoch    7/250 = train loss: 0.6903, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07557487487792969s
# Epoch    8/250 = train loss: 0.6901, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07676386833190918s
# Epoch    9/250 = train loss: 0.6899, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07601475715637207s
# Epoch   10/250 = train loss: 0.6898, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07809829711914062s
# Epoch   11/250 = train loss: 0.6899, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07866597175598145s
# Epoch   12/250 = train loss: 0.6898, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.0790400505065918s
# Epoch   13/250 = train loss: 0.6895, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07738113403320312s
# Epoch   14/250 = train loss: 0.6897, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.0778038501739502s
# Epoch   15/250 = train loss: 0.6896, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07534384727478027s
# Epoch   16/250 = train loss: 0.6898, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07611584663391113s
# Epoch   17/250 = train loss: 0.6899, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.0784158706665039s
# Epoch   18/250 = train loss: 0.6892, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07882404327392578s
# Epoch   19/250 = train loss: 0.6892, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07660794258117676s
# Epoch   20/250 = train loss: 0.6889, train ACC: 0.5406, val ACC: 0.5447, time_taken: 0.08051300048828125s
# Epoch   21/250 = train loss: 0.6891, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.0764460563659668s
# Epoch   22/250 = train loss: 0.6892, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07720184326171875s
# Epoch   23/250 = train loss: 0.6893, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07448410987854004s
# Epoch   24/250 = train loss: 0.6890, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07651114463806152s
# Epoch   25/250 = train loss: 0.6892, train ACC: 0.5431, val ACC: 0.5447, time_taken: 0.07643818855285645s
# Epoch   26/250 = train loss: 0.6887, train ACC: 0.5458, val ACC: 0.5412, time_taken: 0.07692098617553711s
# Epoch   27/250 = train loss: 0.6890, train ACC: 0.5457, val ACC: 0.5426, time_taken: 0.07889914512634277s
# Epoch   28/250 = train loss: 0.6889, train ACC: 0.5435, val ACC: 0.5438, time_taken: 0.07969903945922852s
# Epoch   29/250 = train loss: 0.6887, train ACC: 0.5429, val ACC: 0.5441, time_taken: 0.0791330337524414s
# Epoch   30/250 = train loss: 0.6889, train ACC: 0.5425, val ACC: 0.5441, time_taken: 0.07610487937927246s
# Epoch   31/250 = train loss: 0.6884, train ACC: 0.5460, val ACC: 0.5405, time_taken: 0.07732319831848145s
# Epoch   32/250 = train loss: 0.6885, train ACC: 0.5469, val ACC: 0.5338, time_taken: 0.07743382453918457s
# Epoch   33/250 = train loss: 0.6887, train ACC: 0.5453, val ACC: 0.5440, time_taken: 0.07738995552062988s
# Epoch   34/250 = train loss: 0.6891, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07782483100891113s
# Epoch   35/250 = train loss: 0.6888, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.08046388626098633s
# Epoch   36/250 = train loss: 0.6886, train ACC: 0.5420, val ACC: 0.5443, time_taken: 0.07790613174438477s
# Epoch   37/250 = train loss: 0.6888, train ACC: 0.5468, val ACC: 0.5420, time_taken: 0.07676100730895996s
# Epoch   38/250 = train loss: 0.6886, train ACC: 0.5466, val ACC: 0.5366, time_taken: 0.07568168640136719s
# Epoch   39/250 = train loss: 0.6886, train ACC: 0.5469, val ACC: 0.5422, time_taken: 0.07972502708435059s
# Epoch   40/250 = train loss: 0.6883, train ACC: 0.5446, val ACC: 0.5441, time_taken: 0.07812786102294922s
# Epoch   41/250 = train loss: 0.6885, train ACC: 0.5399, val ACC: 0.5443, time_taken: 0.0828101634979248s
# Epoch   42/250 = train loss: 0.6881, train ACC: 0.5429, val ACC: 0.5443, time_taken: 0.08034420013427734s
# Epoch   43/250 = train loss: 0.6882, train ACC: 0.5465, val ACC: 0.5426, time_taken: 0.08273506164550781s
# Epoch   44/250 = train loss: 0.6885, train ACC: 0.5463, val ACC: 0.5418, time_taken: 0.07683920860290527s
# Epoch   45/250 = train loss: 0.6884, train ACC: 0.5451, val ACC: 0.5440, time_taken: 0.0775911808013916s
# Epoch   46/250 = train loss: 0.6885, train ACC: 0.5426, val ACC: 0.5443, time_taken: 0.07868695259094238s
# Epoch   47/250 = train loss: 0.6885, train ACC: 0.5413, val ACC: 0.5443, time_taken: 0.07692599296569824s
# Epoch   48/250 = train loss: 0.6886, train ACC: 0.5426, val ACC: 0.5443, time_taken: 0.0784139633178711s
# Epoch   49/250 = train loss: 0.6887, train ACC: 0.5454, val ACC: 0.5443, time_taken: 0.08299612998962402s
# Epoch   50/250 = train loss: 0.6882, train ACC: 0.5461, val ACC: 0.5412, time_taken: 0.07816600799560547s
# Epoch   51/250 = train loss: 0.6882, train ACC: 0.5466, val ACC: 0.5391, time_taken: 0.07512927055358887s
# Epoch   52/250 = train loss: 0.6882, train ACC: 0.5463, val ACC: 0.5418, time_taken: 0.07872509956359863s
# Epoch   53/250 = train loss: 0.6883, train ACC: 0.5454, val ACC: 0.5436, time_taken: 0.0791940689086914s
# Epoch   54/250 = train loss: 0.6883, train ACC: 0.5454, val ACC: 0.5445, time_taken: 0.07663297653198242s
# Epoch   55/250 = train loss: 0.6881, train ACC: 0.5456, val ACC: 0.5440, time_taken: 0.07746028900146484s
# Epoch   56/250 = train loss: 0.6883, train ACC: 0.5468, val ACC: 0.5408, time_taken: 0.07742428779602051s
# Epoch   57/250 = train loss: 0.6879, train ACC: 0.5472, val ACC: 0.5401, time_taken: 0.07688331604003906s
# Epoch   58/250 = train loss: 0.6882, train ACC: 0.5469, val ACC: 0.5416, time_taken: 0.10614180564880371s
# Epoch   59/250 = train loss: 0.6882, train ACC: 0.5474, val ACC: 0.5422, time_taken: 0.08109593391418457s
# Epoch   60/250 = train loss: 0.6878, train ACC: 0.5473, val ACC: 0.5418, time_taken: 0.08089804649353027s
# Epoch   61/250 = train loss: 0.6877, train ACC: 0.5472, val ACC: 0.5410, time_taken: 0.08014416694641113s
# Epoch   62/250 = train loss: 0.6880, train ACC: 0.5473, val ACC: 0.5422, time_taken: 0.07649397850036621s
# Epoch   63/250 = train loss: 0.6876, train ACC: 0.5472, val ACC: 0.5412, time_taken: 0.07874083518981934s
# Epoch   64/250 = train loss: 0.6878, train ACC: 0.5466, val ACC: 0.5410, time_taken: 0.07911205291748047s
# Epoch   65/250 = train loss: 0.6881, train ACC: 0.5466, val ACC: 0.5420, time_taken: 0.07407617568969727s
# Epoch   66/250 = train loss: 0.6879, train ACC: 0.5400, val ACC: 0.5443, time_taken: 0.07698297500610352s
# Epoch   67/250 = train loss: 0.6880, train ACC: 0.5436, val ACC: 0.5443, time_taken: 0.07465791702270508s
# Epoch   68/250 = train loss: 0.6881, train ACC: 0.5470, val ACC: 0.5424, time_taken: 0.0774080753326416s
# Epoch   69/250 = train loss: 0.6876, train ACC: 0.5479, val ACC: 0.5383, time_taken: 0.07872200012207031s
# Epoch   70/250 = train loss: 0.6875, train ACC: 0.5479, val ACC: 0.5362, time_taken: 0.07816910743713379s
# Epoch   71/250 = train loss: 0.6882, train ACC: 0.5476, val ACC: 0.5395, time_taken: 0.07976388931274414s
# Epoch   72/250 = train loss: 0.6875, train ACC: 0.5470, val ACC: 0.5436, time_taken: 0.0784902572631836s
# Epoch   73/250 = train loss: 0.6874, train ACC: 0.5470, val ACC: 0.5420, time_taken: 0.07802200317382812s
# Epoch   74/250 = train loss: 0.6878, train ACC: 0.5477, val ACC: 0.5416, time_taken: 0.07631993293762207s
# Epoch   75/250 = train loss: 0.6876, train ACC: 0.5474, val ACC: 0.5383, time_taken: 0.07703089714050293s
# Epoch   76/250 = train loss: 0.6879, train ACC: 0.5474, val ACC: 0.5387, time_taken: 0.07845878601074219s
# Epoch   77/250 = train loss: 0.6876, train ACC: 0.5473, val ACC: 0.5391, time_taken: 0.07419800758361816s
# Epoch   78/250 = train loss: 0.6878, train ACC: 0.5472, val ACC: 0.5430, time_taken: 0.07366776466369629s
# Epoch   79/250 = train loss: 0.6877, train ACC: 0.5468, val ACC: 0.5414, time_taken: 0.07572126388549805s
# Epoch   80/250 = train loss: 0.6879, train ACC: 0.5472, val ACC: 0.5410, time_taken: 0.07822895050048828s
# Epoch   81/250 = train loss: 0.6875, train ACC: 0.5479, val ACC: 0.5389, time_taken: 0.07984519004821777s
# Epoch   82/250 = train loss: 0.6877, train ACC: 0.5478, val ACC: 0.5362, time_taken: 0.07843875885009766s
# Epoch   83/250 = train loss: 0.6876, train ACC: 0.5475, val ACC: 0.5381, time_taken: 0.07717418670654297s
# Epoch   84/250 = train loss: 0.6875, train ACC: 0.5478, val ACC: 0.5401, time_taken: 0.07786393165588379s
# Epoch   85/250 = train loss: 0.6881, train ACC: 0.5464, val ACC: 0.5420, time_taken: 0.07695984840393066s
# Epoch   86/250 = train loss: 0.6874, train ACC: 0.5450, val ACC: 0.5440, time_taken: 0.07771897315979004s
# Epoch   87/250 = train loss: 0.6875, train ACC: 0.5471, val ACC: 0.5410, time_taken: 0.07920289039611816s
# Epoch   88/250 = train loss: 0.6875, train ACC: 0.5474, val ACC: 0.5383, time_taken: 0.08326411247253418s
# Epoch   89/250 = train loss: 0.6875, train ACC: 0.5481, val ACC: 0.5358, time_taken: 0.0762019157409668s
# Epoch   90/250 = train loss: 0.6873, train ACC: 0.5481, val ACC: 0.5375, time_taken: 0.0788722038269043s
# Epoch   91/250 = train loss: 0.6876, train ACC: 0.5477, val ACC: 0.5391, time_taken: 0.08066391944885254s
# Epoch   92/250 = train loss: 0.6874, train ACC: 0.5480, val ACC: 0.5379, time_taken: 0.07634305953979492s
# Epoch   93/250 = train loss: 0.6878, train ACC: 0.5477, val ACC: 0.5408, time_taken: 0.07830810546875s
# Epoch   94/250 = train loss: 0.6877, train ACC: 0.5469, val ACC: 0.5441, time_taken: 0.07867121696472168s
# Epoch   95/250 = train loss: 0.6872, train ACC: 0.5474, val ACC: 0.5420, time_taken: 0.08495378494262695s
# Epoch   96/250 = train loss: 0.6871, train ACC: 0.5479, val ACC: 0.5373, time_taken: 0.07633471488952637s
# Epoch   97/250 = train loss: 0.6870, train ACC: 0.5481, val ACC: 0.5385, time_taken: 0.07789969444274902s
# Epoch   98/250 = train loss: 0.6871, train ACC: 0.5480, val ACC: 0.5391, time_taken: 0.07785391807556152s
# Epoch   99/250 = train loss: 0.6870, train ACC: 0.5479, val ACC: 0.5387, time_taken: 0.07484006881713867s
# Epoch  100/250 = train loss: 0.6868, train ACC: 0.5470, val ACC: 0.5422, time_taken: 0.0777888298034668s
# Epoch  101/250 = train loss: 0.6874, train ACC: 0.5466, val ACC: 0.5420, time_taken: 0.07889509201049805s
# Epoch  102/250 = train loss: 0.6872, train ACC: 0.5467, val ACC: 0.5403, time_taken: 0.07670807838439941s
# Epoch  103/250 = train loss: 0.6871, train ACC: 0.5469, val ACC: 0.5414, time_taken: 0.07830286026000977s
# Epoch  104/250 = train loss: 0.6874, train ACC: 0.5477, val ACC: 0.5416, time_taken: 0.08117818832397461s
# Epoch  105/250 = train loss: 0.6871, train ACC: 0.5482, val ACC: 0.5381, time_taken: 0.07823705673217773s
# Epoch  106/250 = train loss: 0.6872, train ACC: 0.5484, val ACC: 0.5356, time_taken: 0.07751131057739258s
# Epoch  107/250 = train loss: 0.6874, train ACC: 0.5481, val ACC: 0.5401, time_taken: 0.07526993751525879s
# Epoch  108/250 = train loss: 0.6873, train ACC: 0.5476, val ACC: 0.5416, time_taken: 0.07609415054321289s
# Epoch  109/250 = train loss: 0.6870, train ACC: 0.5479, val ACC: 0.5412, time_taken: 0.07706713676452637s
# Epoch  110/250 = train loss: 0.6869, train ACC: 0.5486, val ACC: 0.5406, time_taken: 0.07587194442749023s
# Epoch  111/250 = train loss: 0.6871, train ACC: 0.5483, val ACC: 0.5375, time_taken: 0.07760977745056152s
# Epoch  112/250 = train loss: 0.6871, train ACC: 0.5483, val ACC: 0.5373, time_taken: 0.08069896697998047s
# Epoch  113/250 = train loss: 0.6866, train ACC: 0.5484, val ACC: 0.5375, time_taken: 0.07762479782104492s
# Epoch  114/250 = train loss: 0.6869, train ACC: 0.5487, val ACC: 0.5387, time_taken: 0.07530069351196289s
# Epoch  115/250 = train loss: 0.6872, train ACC: 0.5489, val ACC: 0.5418, time_taken: 0.07687497138977051s
# Epoch  116/250 = train loss: 0.6870, train ACC: 0.5490, val ACC: 0.5420, time_taken: 0.07859396934509277s
# Epoch  117/250 = train loss: 0.6869, train ACC: 0.5490, val ACC: 0.5430, time_taken: 0.07892203330993652s
# Epoch  118/250 = train loss: 0.6872, train ACC: 0.5491, val ACC: 0.5408, time_taken: 0.08174800872802734s
# Epoch  119/250 = train loss: 0.6867, train ACC: 0.5486, val ACC: 0.5405, time_taken: 0.09800100326538086s
# Epoch  120/250 = train loss: 0.6868, train ACC: 0.5488, val ACC: 0.5364, time_taken: 0.07644510269165039s
# Epoch  121/250 = train loss: 0.6870, train ACC: 0.5483, val ACC: 0.5387, time_taken: 0.08043408393859863s
# Epoch  122/250 = train loss: 0.6868, train ACC: 0.5482, val ACC: 0.5387, time_taken: 0.0783998966217041s
# Epoch  123/250 = train loss: 0.6870, train ACC: 0.5480, val ACC: 0.5395, time_taken: 0.08016800880432129s
# Epoch  124/250 = train loss: 0.6867, train ACC: 0.5481, val ACC: 0.5399, time_taken: 0.07952189445495605s
# Epoch  125/250 = train loss: 0.6871, train ACC: 0.5481, val ACC: 0.5391, time_taken: 0.07775306701660156s
# Epoch  126/250 = train loss: 0.6870, train ACC: 0.5478, val ACC: 0.5406, time_taken: 0.07738900184631348s
# Epoch  127/250 = train loss: 0.6869, train ACC: 0.5491, val ACC: 0.5381, time_taken: 0.08089613914489746s
# Epoch  128/250 = train loss: 0.6863, train ACC: 0.5488, val ACC: 0.5364, time_taken: 0.07870078086853027s
# Epoch  129/250 = train loss: 0.6872, train ACC: 0.5494, val ACC: 0.5389, time_taken: 0.07857799530029297s
# Epoch  130/250 = train loss: 0.6865, train ACC: 0.5494, val ACC: 0.5366, time_taken: 0.07718825340270996s
# Epoch  131/250 = train loss: 0.6871, train ACC: 0.5485, val ACC: 0.5391, time_taken: 0.07581210136413574s
# Epoch  132/250 = train loss: 0.6867, train ACC: 0.5481, val ACC: 0.5441, time_taken: 0.08151793479919434s
# Epoch  133/250 = train loss: 0.6870, train ACC: 0.5472, val ACC: 0.5438, time_taken: 0.07604193687438965s
# Epoch  134/250 = train loss: 0.6871, train ACC: 0.5488, val ACC: 0.5422, time_taken: 0.07857298851013184s
# Epoch  135/250 = train loss: 0.6868, train ACC: 0.5492, val ACC: 0.5410, time_taken: 0.07952094078063965s
# Epoch  136/250 = train loss: 0.6868, train ACC: 0.5486, val ACC: 0.5395, time_taken: 0.07716012001037598s
# Epoch  137/250 = train loss: 0.6867, train ACC: 0.5491, val ACC: 0.5371, time_taken: 0.07784700393676758s
# Epoch  138/250 = train loss: 0.6870, train ACC: 0.5488, val ACC: 0.5412, time_taken: 0.07632112503051758s
# Epoch  139/250 = train loss: 0.6864, train ACC: 0.5488, val ACC: 0.5393, time_taken: 0.07810306549072266s
# Epoch  140/250 = train loss: 0.6867, train ACC: 0.5489, val ACC: 0.5395, time_taken: 0.0784451961517334s
# Epoch  141/250 = train loss: 0.6867, train ACC: 0.5490, val ACC: 0.5416, time_taken: 0.07710790634155273s
# Epoch  142/250 = train loss: 0.6867, train ACC: 0.5492, val ACC: 0.5387, time_taken: 0.07785487174987793s
# Best loss: 0.686302 best train: 0.5494 best val: 0.5447
# done

# %%
best_model = loadLSTMLinearFromCheckpoint(f'../data/checkpoints/checkpoint_{filename}.pkl')
best_model_f1 = loadLSTMLinearFromCheckpoint(f'../data/checkpoints/checkpoint_{filename}_f1.pkl')

printScores(test_dl, val_dl, best_model)
printScores(test_dl, val_dl, best_model_f1)
# Out:
# test R2: -0.0038, val R2: -0.0025
# test R2: 0.0003, val R2: -0.0030
